# %%
from mp_api.client import MPRester

# %%
with MPRester(api_key = 'OrhOWaCCK3NJeCNjeIcTPN7H6AmuOTGT') as mpr:
    doc_s = mpr.summary.get_data_by_id('mp-804')
    doc_m = mpr.materials.get_data_by_id('mp-804')
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python38\site-packages\mp_api\client.py:138: builtins.UserWarning: Problem loading MPContribs client: [<twisted.python.failure.Failure OpenSSL.SSL.Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]>]
# ...
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
doc_s

# %%
doc_m

# %%
doc_m.composition
# Out:
# Comp: Ga2 N2

# %%
doc_m.structure
# Out:
# Structure Summary
# Lattice
#     abc : 3.2162901334217344 3.2162901334217344 5.239962
#  angles : 90.0 90.0 120.00000274450079
#  volume : 46.9428220153705
#       A : 1.608145 -2.785389 0.0
#       B : 1.608145 2.785389 0.0
#       C : 0.0 0.0 5.239962
# PeriodicSite: Ga (1.6081, -0.9285, 2.6154) [0.6667, 0.3333, 0.4991]
# PeriodicSite: Ga (1.6081, 0.9285, 5.2354) [0.3333, 0.6667, 0.9991]
# PeriodicSite: N (1.6081, -0.9285, 4.5896) [0.6667, 0.3333, 0.8759]
# PeriodicSite: N (1.6081, 0.9285, 1.9696) [0.3333, 0.6667, 0.3759]

# %%
doc_m.structure.get_distance(0, 2)
# Out:
# 1.9742080831200006

# %%
doc_m.structure.get_all_neighbors(2.0)
# Out:
# [[PeriodicSite: N (-0.0000, -1.8569, 1.9696) [0.3333, -0.3333, 0.3759],
#   PeriodicSite: N (3.2163, -1.8569, 1.9696) [1.3333, 0.6667, 0.3759],
#   PeriodicSite: N (1.6081, 0.9285, 1.9696) [0.3333, 0.6667, 0.3759],
#   PeriodicSite: N (1.6081, -0.9285, 4.5896) [0.6667, 0.3333, 0.8759]],
#  [PeriodicSite: N (0.0000, 1.8569, 4.5896) [-0.3333, 0.3333, 0.8759],
#   PeriodicSite: N (1.6081, -0.9285, 4.5896) [0.6667, 0.3333, 0.8759],
#   PeriodicSite: N (1.6081, 0.9285, 7.2096) [0.3333, 0.6667, 1.3759],
#   PeriodicSite: N (3.2163, 1.8569, 4.5896) [0.6667, 1.3333, 0.8759]],
#  [PeriodicSite: Ga (-0.0000, -1.8569, 5.2354) [0.3333, -0.3333, 0.9991],
#   PeriodicSite: Ga (3.2163, -1.8569, 5.2354) [1.3333, 0.6667, 0.9991],
#   PeriodicSite: Ga (1.6081, -0.9285, 2.6154) [0.6667, 0.3333, 0.4991],
#   PeriodicSite: Ga (1.6081, 0.9285, 5.2354) [0.3333, 0.6667, 0.9991]],
#  [PeriodicSite: Ga (0.0000, 1.8569, 2.6154) [-0.3333, 0.3333, 0.4991],
# ...

# %%
doc_m.structure.to(filename = 'GaN.cif')

# %%
# %ls
# Out:
#  驱动器 C 中的卷是 Windows-SSD
#  卷的序列号是 1057-C378
#
#  C:\Users\Jarvis\Desktop\ML-cur\machine_learning 的目录
#
# 2022/10/28  21:19    <DIR>          .
# 2022/10/17  10:20    <DIR>          ..
# 2022/10/28  16:11    <DIR>          .ipynb_checkpoints
# 2022/10/17  17:10            25,587 2_linear_regression.ipynb
# 2022/10/17  16:21            59,015 2_n_linear_regression.ipynb
# 2022/10/17  14:31            24,133 2_non_linear_regression.ipynb
# 2022/07/06  16:40            12,577 2Dmini.png
# 2022/10/17  17:10             9,660 4_Decision_Tree.ipynb
# 2022/10/27  11:29           102,278 4_Decision_Tree_test.ipynb
# 2022/10/27  16:10           228,411 4_MOF_Classification.ipynb
# 2022/10/28  10:49           429,820 5_Regression.ipynb
# 2022/10/28  12:03            43,237 6_Neural_Network.ipynb
# 2022/10/28  11:25            42,183 6_Support_Vector_Machine_Regression.ipynb
# 2022/10/28  16:10            61,147 7_High_Throughput_Screening.ipynb
# ...

# %%
doc_m.structure.to(filename='POSCAR')

# %%
# %ls
# Out:
#  驱动器 C 中的卷是 Windows-SSD
#  卷的序列号是 1057-C378
#
#  C:\Users\Jarvis\Desktop\ML-cur\machine_learning 的目录
#
# 2022/10/28  21:20    <DIR>          .
# 2022/10/17  10:20    <DIR>          ..
# 2022/10/28  16:11    <DIR>          .ipynb_checkpoints
# 2022/10/17  17:10            25,587 2_linear_regression.ipynb
# 2022/10/17  16:21            59,015 2_n_linear_regression.ipynb
# 2022/10/17  14:31            24,133 2_non_linear_regression.ipynb
# 2022/07/06  16:40            12,577 2Dmini.png
# 2022/10/17  17:10             9,660 4_Decision_Tree.ipynb
# 2022/10/27  11:29           102,278 4_Decision_Tree_test.ipynb
# 2022/10/27  16:10           228,411 4_MOF_Classification.ipynb
# 2022/10/28  10:49           429,820 5_Regression.ipynb
# 2022/10/28  12:03            43,237 6_Neural_Network.ipynb
# 2022/10/28  11:25            42,183 6_Support_Vector_Machine_Regression.ipynb
# 2022/10/28  16:10            61,147 7_High_Throughput_Screening.ipynb
# ...

# %%
list_of_available_fields = mpr.summary.available_fields #可以筛选的标签
list_of_available_fields
# Out:
# ['builder_meta',
#  'nsites',
#  'elements',
#  'nelements',
#  'composition',
#  'composition_reduced',
#  'formula_pretty',
#  'formula_anonymous',
#  'chemsys',
#  'volume',
#  'density',
#  'density_atomic',
#  'symmetry',
#  'property_name',
#  'material_id',
#  'deprecated',
#  'deprecation_reasons',
#  'last_updated',
#  'origins',
#  'warnings',
#  'structure',
#  'task_ids',
#  'uncorrected_energy_per_atom',
#  'energy_per_atom',
#  'formation_energy_per_atom',
#  'energy_above_hull',
#  'is_stable',
#  'equilibrium_reaction_energy_per_atom',
#  'decomposes_to',
#  'xas',
#  'grain_boundaries',
#  'band_gap',
#  'cbm',
#  'vbm',
#  'efermi',
#  'is_gap_direct',
#  'is_metal',
#  'es_source_calc_id',
#  'bandstructure',
#  'dos',
#  'dos_energy_up',
#  'dos_energy_down',
#  'is_magnetic',
#  'ordering',
#  'total_magnetization',
#  'total_magnetization_normalized_vol',
#  'total_magnetization_normalized_formula_units',
#  'num_magnetic_sites',
#  'num_unique_magnetic_sites',
# ...

# %%
docs = mpr.summary.search(elements=['Si', 'O'], band_gap = (0.5, 1.0))
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/332 [00:00<?, ?it/s]

# %%
docs
# Out:
# [SummaryDoc(builder_meta=EmmetMeta(emmet_version='0.36.9', pymatgen_version='2022.4.19', pull_request=None, database_version=None, build_date=datetime.datetime(2022, 10, 5, 21, 51, 0, 284000)), nsites=52, elements=[Element Al, Element N, Element Na, Element O, Element Si], nelements=5, composition=Comp: Na8 Al6 Si6 N2 O30, composition_reduced=Comp: Na4 Al3 Si3 N1 O15, formula_pretty='Na4Al3Si3NO15', formula_anonymous='AB3C3D4E15', chemsys='Al-N-Na-O-Si', volume=784.7812509534215, density=2.163144568918805, density_atomic=15.091947133719644, symmetry=SymmetryData(crystal_system=<CrystalSystem.tri: 'Triclinic'>, symbol='P1', number=1, point_group='1', symprec=0.1, version='1.16.2'), property_name='summary', material_id=MPID(mp-1173811), deprecated=False, deprecation_reasons=None, last_updated=datetime.datetime(2022, 10, 5, 21, 51, 0, 284000), origins=[], warnings=[], structure=Structure Summary
#  Lattice
#      abc : 9.151609 9.2466132209542 9.279126456568259
# ...

# %%
docs = mpr.summary.search(elements=['Si', 'O'], band_gap = (0.5, None), energy_above_hull = (0, 0), fields = ['material_id', 'composition', 'band_gap', 'volume', 'structure'])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
len(docs)
# Out:
# 625

# %%
docs[0].band_gap
# Out:
# 2.4113

# %%
import pandas as pd

# %%
stable_mpids = []

for doc in docs:
    stable_mpids.append(doc.material_id)

# %%
stable_mpids = pd.DataFrame(stable_mpids) #转化为dataframe
stable_mpids
# Out:
#               0
# 0     mp-541929
# 1     mp-694049
# 2     mp-560478
# 3    mp-1197149
# 4    mp-1192403
# ..          ...
# 620  mp-1019558
# 621  mp-1221115
# 622   mp-560638
# 623  mp-1223595
# 624    mp-18460
#
# [625 rows x 1 columns]

# %%
with MPRester(api_key='OrhOWaCCK3NJeCNjeIcTPN7H6AmuOTGT') as mpr:
    docs = mpr.summary.search(elements=['Li'], band_gap=(0.5, None), energy_above_hull=(None, 0.005), fields = ['material_id', 'formula_pretty', 'composition', 'band_gap', 'energy_above_hull', 'structure'])
# Out:
# C:\Users\Jarvis\AppData\Roaming\Python\Python38\site-packages\mp_api\client.py:138: builtins.UserWarning: Problem loading MPContribs client: [<twisted.python.failure.Failure OpenSSL.SSL.Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]>]
# Retrieving SummaryDoc documents:   0%|          | 0/1690 [00:00<?, ?it/s]

# %%
df = []

for doc in docs:
    df.append([doc.material_id, doc.formula_pretty, doc.composition, doc.band_gap, doc.energy_above_hull, doc.structure])

# %%
df = pd.DataFrame(df, columns = ['mp-id', 'formula', 'composition', 'band_gap', 'energy_above_hull', 'structure'])
df
# Out:
#            mp-id         formula         composition  band_gap  \
# 0      mp-559938     LiV3(TeO6)2      (Li, V, Te, O)    1.8361
# 1        mp-5614          Li3BS3          (Li, B, S)    2.8882
# 2      mp-777795  Li8Mn7Fe(BO3)8  (Li, Mn, Fe, B, O)    2.6565
# 3     mp-1111845      Cs2LiNdBr6    (Cs, Li, Nd, Br)    3.9972
# 4      mp-760164   Li2VFe(P2O7)2   (Li, V, Fe, P, O)    1.7204
# ...          ...             ...                 ...       ...
# 1685     mp-5127           LiCuO         (Li, Cu, O)    1.4376
# 1686  mp-1211213   Li3Tb3(TeO6)2     (Li, Tb, Te, O)    3.5219
# 1687   mp-759377     LiTi2(PO4)3      (Li, Ti, P, O)    2.5726
# 1688   mp-554940         LiCr3O8         (Li, Cr, O)    0.6994
# 1689   mp-778744   Li2MnNi(PO4)2  (Li, Mn, Ni, P, O)    2.6905
#
#       energy_above_hull                                          structure
# 0              0.000000  [[3.46786082 5.37704423 1.17536962] Li, [0.360...
# ...

# %%
df0 = pd.DataFrame([['Fe2O3', 0.5], ['Fe0.5O3', 0.5]])
df0
# Out:
#          0    1
# 0    Fe2O3  0.5
# 1  Fe0.5O3  0.5
