# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HER2.csv')
df
# Out:
#      Unnamed: 0   V1    V2  V3  V4    V5    V6   V7   V8   V9  ...   V18  \
# 0             1  2.2  1.93  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 1             2  2.2  1.93  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 2             3  2.2  1.93  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 3             4  2.2  1.93  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 4             5  2.2  1.93  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# ..          ...  ...   ...  ..  ..   ...   ...  ...  ...  ...  ...   ...
# 458         459  2.2  2.54  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.25
# 459         460  2.2  2.54  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.25
# 460         461  2.2  2.54  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 461         462  2.2  2.54  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
# 462         463  2.2  2.54  10  10  1.37  1.44  1.0  1.0  0.9  ...  0.00
#
#       V19   V20  V21  V22  V23  V24  V25  V26  Eads(H)
# 0    0.60  0.33    4    0    0    2    0    0    -0.51
# 1    0.60  0.33    4    0    0    2    0    0    -0.55
# 2    0.33  0.23    4    0    0    2    0    0    -0.51
# 3    0.45  0.14    4    0    0    2    0    0    -0.47
# 4    0.60  0.33    4    0    0    2    0    0    -0.61
# ..    ...   ...  ...  ...  ...  ...  ...  ...      ...
# 458  2.20  3.00    2    2    0    1    1    0    -0.45
# 459  2.20  3.00    2    2    0    1    1    0    -0.52
# 460  3.00  7.00    4    0    0    2    0    0    -0.53
# 461  2.20  3.00    4    0    0    2    0    0    -0.55
# 462  7.00  4.33    4    0    0    2    0    0    -0.51
#
# [463 rows x 28 columns]

# %%
X = df.drop('Eads(H)', axis = 1)
y = df['Eads(H)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train_s = (X_train - X_train.mean()) / (X_train.max() - X_train.min())
X_test_s = (X_test - X_train.mean()) / (X_train.max() - X_train.min())

# %%
nn = MLPRegressor(hidden_layer_sizes = (64, 64), random_state = 1)

# %%
nn.fit(X_train_s, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(64, 64), random_state=1)

# %%
plt.figure(figsize = (5, 5))
plt.scatter(y_train, nn.predict(X_train_s), c = 'cyan', edgecolor = 'k')
plt.scatter(y_test, nn.predict(X_test_s), c = 'pink', edgecolor = 'k')
plt.plot([-1.0, 2.0], [-1.0, 2.0], 'k--')
plt.xlim(-1, 2)
plt.ylim(-1, 2)
plt.show()
